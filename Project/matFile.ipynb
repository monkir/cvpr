# %%
import mat73
image1 = mat73.loadmat("1.mat")

# %%
import cv2
import matplotlib.pyplot as plt

# %%
for i in image1['cjdata']:
    print (i)
# Out:
# PID
# image
# label
# tumorBorder
# tumorMask

# %%
plt.imshow(image1["cjdata"]["image"])
